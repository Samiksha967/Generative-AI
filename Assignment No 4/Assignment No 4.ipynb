# %% [markdown]
# Build a simple question-answering chatbot using a pre-trained language model

# %%
# !pip install transformers torch
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from transformers import pipeline

qa_pipeline = pipeline(
    "question-answering",
    model="distilbert-base-uncased-distilled-squad"
)

print("Q&A Model Loaded Successfully ✅")
# Out:
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# Q&A Model Loaded Successfully ✅

# %%
CONTEXT = CONTEXT = """
Cyber Security focuses on protecting systems, networks, and data from
digital attacks. These attacks aim to access, change, or destroy sensitive
information. Common security measures include encryption, firewalls,
authentication, and intrusion detection systems.
"""

# %%
def chatbot():
    print("🤖 Question Answering Chatbot")
    print("Type 'exit' to stop\n")
    print("Context is fixed inside the code.\n")

    while True:
        question = input("Ask a question: ")

        if question.lower() == "exit":
            print("Chatbot stopped ❌")
            break

        result = qa_pipeline(
            question=question,
            context=CONTEXT
        )

        print("\nQuestion:", question)
        print("Answer:", result["answer"])
        print("-" * 40)

# %%
chatbot()
# Out:
# 🤖 Question Answering Chatbot
# Type 'exit' to stop
#
# Context is fixed inside the code.
#
#
# Question: What is Cyber Security
# Answer: protecting systems, networks, and data from
# digital attacks
# ----------------------------------------
#
# Question: What are common security measures
# Answer: encryption, firewalls,
# authentication, and intrusion detection systems
# ----------------------------------------
#
# Question: What is encryption
# Answer: intrusion detection systems
# ----------------------------------------
#
# Question: Which systems are protected by Cyber Security
# Answer: intrusion detection systems
# ----------------------------------------
# Chatbot stopped ❌
